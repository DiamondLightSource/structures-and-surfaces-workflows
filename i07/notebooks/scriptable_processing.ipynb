# %%
import json
import sys

if type(scans)==str:
    scan_numbers=json.loads(scans.replace("  ", " ,"))
else:
    scan_numbers=scans
debuglogging=0
python_version=sys.executable
version_path='/app/'
# %run -i '{calc_file}'

# %%
with open(exp_file, 'r') as file:
    print(file.read())

# %%
with open(calc_file, 'r') as file:
    print(file.read())
