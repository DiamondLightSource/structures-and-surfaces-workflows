# %%
import json
import sys

def parse_scan_list(scans):
    if type(scans) is str:
        return json.loads(scans.replace(" ", " ,"))
    else:
        return scans
debuglogging=0
python_version=sys.executable
version_path='/app/'

scan_numbers = None
scan_range = None
if scan_list.startswith('-s '):
    outscans=scan_list.replace('-s ','')
    scan_numbers = parse_scan_list(f"[{outscans}]")
elif scan_list.startswith('-sr '):
    outscans=scan_list.replace('-sr ','')
    scan_range = f"{parse_scan_list(outscans)}"

# %%
from fast_rsm.diamond_utils import ProcessArgs

process_args = ProcessArgs(exp_path=exp_file,
                           calc_path=calc_file, 
                           python_version=python_version, 
                           version_path=version_path, 
                           scan_nums=scan_numbers, 
                           scan_range=scan_range,
                           local=1)

# %%
process_args.parse_and_reduce()
# Out:
# ...
# Please check https://fast-rsm.readthedocs.io/ for the latest exp_setup format
# Done
# ...
# Please check https://fast-rsm.readthedocs.io/ for the latest exp_setup format
# config values loaded
# /dls/science/users/rpy65944/I07_work/dev_mapping/diffraction_utils/src/diffraction_utils/io.py:101: MissingMetadataWarning: _parse_attenuation_filters_moving failed to parse a value, so its value will default to None.
#   warn(
# Took 0.2763490676879883s to load all nexus files.
#   completed 1/1 batches
# total calculation took 0.017017610867818198  minutes
# saved 2d Qmap data to            /dls/i07/data/2026/cm44146-1/ExampleData/output/Qmap_432196_2026-06-19_15h45m24s.hdf5
#
#  2d Qmap calculations took 0.01945162614186605 minutes
#   completed 1/1 batches
# saved 1d integration  data to            /dls/i07/data/2026/cm44146-1/ExampleData/output/IvsQ_432196_2026-06-19_15h45m25s.hdf5
#
#  1d integration  calculations took 0.014460782210032145 minutes
#   completed 1/1 batches
# ...

# %%
process_args.print_exp_lines()
# Out:
# """
# First we need to import some stuff.
# If you're interested, each import has an associated comment that explains why
# the import is useful/necessary.
# """
#
# import os
# import multiprocessing
# from pathlib import Path
# import numpy as np
# from fast_rsm.logging_config import configure_logging, get_frsm_logger
# from diffraction_utils import Frame, Region
# from fast_rsm.experiment import Experiment
#
# #=====================EXPERIMENTAL DETAILS============
# # How was your sample mounted? Options are 'horizontal', 'vertical' and 'DCD'.
# setup = 'vertical'
#
# #which experimental hutch was used 0 = unsure, 1= experimental hutch 1, 2=experimental hutch 2
# experimental_hutch=1
# # Set this to the directory path where your files are saved, note you will need to include any subdirectories in this path
# local_data_path =   '/dls/i07/data/2026/cm44146-1/ExampleData'  # '/dls/i07/data/2024/##experiment-number##/##subfolder##
# ...

# %%
process_args.print_calc_lines()
# Out:
# from fast_rsm.diamond_utils import run_process_list, setup_processing
# from fast_rsm.logging_config import start_frsm_loggers
#
# if debuglogging:
#     err_logger, dbg_logger = start_frsm_loggers(version_path, debuglogging)
#
#
# # create experiment object, process configuration and logger
# experiment, process_config = setup_processing(
#     exp_file, __file__, scan_numbers, debuglogging
# )
# # =================================================================================
# ####============SPECIAL ADJUSTMENTS ==============================================
# # #This section is for changing metadata that is stored in, or inferred from, the
# # #nexus file. This is generally for more nonstandard stuff.
# # #uncomment loop over scans to adjust metadata within each scan
# # for i, scan in enumerate(experiment.scans):
# #     """
# #     area for making special adjustments to metadata information
# #     """
# ...
